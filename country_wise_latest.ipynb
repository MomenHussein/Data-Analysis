# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


# In[59]:


data = pd.read_csv("country_wise_latest.csv")
"""y = np.array(data[0:186])
x = np.array(['Country/Region','Confirmed','Deaths','Recovered','Active','New cases	New deaths','New recovered	Deaths / 100 Cases','Recovered / 100 Cases','Deaths / 100 Recovered','Confirmed last week','1 week change','1 week % increase','WHO Region'])"""
# Out:
# "y = np.array(data[0:186])\nx = np.array(['Country/Region','Confirmed','Deaths','Recovered','Active','New cases\tNew deaths','New recovered\tDeaths / 100 Cases','Recovered / 100 Cases','Deaths / 100 Recovered','Confirmed last week','1 week change','1 week % increase','WHO Region'])"

# %%
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
# In[62]:

column_names = ["Confirmed", "Deaths", "Recovered", "Active"]
data[column_names].sum().plot(kind="bar")

plt.show()
# In[63]:


data[column_names].sum().plot()

country_deaths = data[['Country/Region', 'Deaths']].sort_values(by='Deaths', ascending=False)
plt.bar(country_deaths['Country/Region'].head(10), country_deaths['Deaths'].head(10))
plt.xticks(rotation=80)
plt.show()

# %%
country_deaths = data[['Country/Region', 'Confirmed']].sort_values(by='Confirmed', ascending=False)
plt.bar(country_deaths['Country/Region'].head(10), country_deaths['Confirmed'].head(10))
plt.xticks(rotation=80)
plt.show()

# %%
country_deaths = data[['Country/Region', 'Recovered']].sort_values(by='Recovered', ascending=False)
plt.bar(country_deaths['Country/Region'].head(10), country_deaths['Recovered'].head(10))
plt.xticks(rotation=80)
plt.show()

# %%
country_deaths = data[['Country/Region', 'Active']].sort_values(by='Active', ascending=False)
plt.bar(country_deaths['Country/Region'].head(10), country_deaths['Active'].head(10))
plt.xticks(rotation=80)
plt.show()

# %%
plt.hist(country_deaths['Active'].head(10))
plt.xticks(rotation=80)
plt.show()

# %%
data = pd.read_csv('country_wise_latest.csv')
recovered = data["Recovered"].sum()
death = data["Deaths"].sum()
data = [recovered, death]
labels = ["Recovered cases", "Deaths"]

pie = plt.pie(data, labels=labels, autopct="%.2f%%")

# %%
"""import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output 
app.layout =html.Div([
                html.H3("Coronavirus", style={"margin-bottom": "0px", 'color': 'white'}),
            ]),
            html.Div([
        html.Div([
            html.H6(children='Country/Region',
            dcc.Graph(figure=fig),
        html.Div([
            html.H6(children='Deaths',
                    style={'textAlign': 'center', 'color': 'white'}),
        ],

        html.Div([
            html.H6(children='Recovered',
                    style={'textAlign': 'center', 'color': 'white'}),
        ],

        html.Div([
            html.H6(children='Active',
                    style={'textAlign': 'center', 'color': 'white'}),
        ],
    ]"""
# Out:
# 'import dash_core_components as dcc\nimport dash_html_components as html\nfrom dash.dependencies import Input, Output \napp.layout =html.Div([\n                html.H3("Coronavirus", style={"margin-bottom": "0px", \'color\': \'white\'}),\n            ]),\n            html.Div([\n        html.Div([\n            html.H6(children=\'Country/Region\',\n            dcc.Graph(figure=fig),\n        html.Div([\n            html.H6(children=\'Deaths\',\n                    style={\'textAlign\': \'center\', \'color\': \'white\'}),\n        ],\n\n        html.Div([\n            html.H6(children=\'Recovered\',\n                    style={\'textAlign\': \'center\', \'color\': \'white\'}),\n        ],\n\n        html.Div([\n            html.H6(children=\'Active\',\n                    style={\'textAlign\': \'center\', \'color\': \'white\'}),\n        ],\n    ]'

# %%
import pandas as pd
data = pd.read_csv("country_wise_latest.csv")
plt.scatter(x= data["Deaths"],y=data["Recovered"])

# %%
import pandas as pd
data = pd.read_csv("country_wise_latest.csv")
x= data["Deaths"]
y=data["Recovered"]
plt.plot(x, y, 'o')

# %%
import pandas as pd
data = pd.read_csv("country_wise_latest.csv")
x= data["Deaths"]
y1=data["Recovered"]
y2=data["Confirmed"]
plt.fill_between(x, y1, y2, color='skyblue', alpha=0.4, label='Area 1-2')
plt.plot(x, y1, label='Line 1', marker='o')
plt.plot(x, y2, label='Line 2', marker='o')
 
# Labels and Title
plt.xlabel('Deaths'), plt.ylabel('Recovered'), plt.title('Deaths/Recovered')
 
# Legend and Display
plt.legend(), plt.show()
# Out:
# (<matplotlib.legend.Legend at 0x27d11e98390>, None)

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
data = pd.read_csv("country_wise_latest.csv")
chart1 = go.Figure()

chart1.add_trace(go.Scatter(x=data['Recovered'], y=data['Deaths'],
                            marker={"color":"blue"},
                            mode="lines"))

chart1.update_layout(height=500,
                     xaxis_title="Recovered",
                     yaxis_title="Deaths",
                     title="Recovered/Deaths")

chart1
# Out:
# <div>                            <div id="86a446b2-7457-4e80-a503-81e11888cf90" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86a446b2-7457-4e80-a503-81e11888cf90")) {                    Plotly.newPlot(                        "86a446b2-7457-4e80-a503-81e11888cf90",                        [{"marker":{"color":"blue"},"mode":"lines","x":[25198,2745,18837,803,242,65,72575,26665,9311,18246,23242,91,36110,125683,94,60492,17452,26,1036,86,21478,4930,63,1846641,138,5585,926,292,301,1550,147,14539,0,1546,810,319954,78869,131161,328,829,5700,3824,10361,3936,2351,852,11428,12605,4977,18,30204,34896,34838,7778,842,191,1923,1025,6386,18,6920,81212,4682,66,922,190314,29801,1374,13,23,32455,6257,803,181,4365,12,5039,3329,1823,951166,58173,255144,77144,23364,2713
# ...

# %%
"""from dash import Dash, dcc, html
import pandas as pd
data = pd.read_csv("country_wise_latest.csv")
app = Dash(__name__)

app.layout = html.Div(
    children=[
        html.H1(children="Covid-19"),
        html.P(
            children=(
                "Analyze corona virus"
            ),
        ),
        dcc.Graph(
            figure={
                "data": [
                    {
                        "x": data["Country/Region"],
                        "y": data["Deaths"],
                        "type": "lines",
                    },
                ],
                "layout": {"title": "Average Price of Deaths"},
            },
            ),
            dcc.Graph(
                figure={
                    "data": [
                        {
                            "x": data["Active"],
                            "y": data["Confirmed"],
                            "type": "lines",
                        },
                    ],
                    "layout": {"title": "Actives and Confirmed"},
                },
            ),
        ]
    )
        
if __name__ == "__main__":
    app.run_server(debug=True)"""
# Out:
# 'from dash import Dash, dcc, html\nimport pandas as pd\ndata = pd.read_csv("country_wise_latest.csv")\napp = Dash(__name__)\n\napp.layout = html.Div(\n    children=[\n        html.H1(children="Covid-19"),\n        html.P(\n            children=(\n                "Analyze corona virus"\n            ),\n        ),\n        dcc.Graph(\n            figure={\n                "data": [\n                    {\n                        "x": data["Country/Region"],\n                        "y": data["Deaths"],\n                        "type": "lines",\n                    },\n                ],\n                "layout": {"title": "Average Price of Deaths"},\n            },\n            ),\n            dcc.Graph(\n                figure={\n                    "data": [\n                        {\n                            "x": data["Active"],\n                            "y": data["Confirmed"],\n                            "type": "lines",\n                        },\n                    ],\
# ...

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("country_wise_latest.csv")
x=data['Recovered']
y=data['Deaths']
plt.rcParams["axes.prop_cycle"] = plt.cycler(
    color=["#4C2A85", "#BE96FF", "#957DAD", "#5E366E", "#A98CCC"])

fig1, ax1 = plt.subplots()
x= data["Deaths"]
y1=data["Recovered"]
y2=data["Confirmed"]
plt.fill_between(x, y1, y2, color='skyblue', alpha=0.4, label='Area 1-2')
plt.plot(x, y1, label='Line 1', marker='o')
plt.plot(x, y2, label='Line 2', marker='o')
ax1.set_title("Recovered/Deaths legend")
ax1.set_xlabel("Recovered")
ax1.set_ylabel("Deaths")
 
# Labels and Title
plt.xlabel('Deaths'), plt.ylabel('Recovered'), plt.title('Deaths/Recovered')
 
# Legend and Display
plt.legend()


fig2, ax2 = plt.subplots()
x= data["Deaths"]
y=data["Recovered"]
plt.plot(x, y, 'o')
ax2.set_title("Recovered/Deaths legend")
ax2.set_xlabel("Recovered")
ax2.set_ylabel("Deaths")
# plt.show()


# plt.show()

fig4, ax4 = plt.subplots()
ax4.plot(list(x), list(y))
ax4.set_title("Recovered/Deaths")
ax4.set_xlabel("Recovered")
ax4.set_ylabel("Deaths")
# plt.show()

fig5, ax5 = plt.subplots()
ax5.fill_between(x,y)
ax5.set_title("Recovered/Deaths sub")
ax5.set_xlabel("Recovered")
ax5.set_ylabel("Deaths")
# plt.show()

# Create a window and add charts
root = tk.Tk()
root.title("Dashboard")
root.state('zoomed')

side_frame = tk.Frame(root, bg="#4C2A85")
side_frame.pack(side="left", fill="y")

label = tk.Label(side_frame, text="Dashboard", bg="#4C2A85", fg="#FFF", font=25)
label.pack(pady=50, padx=20)

charts_frame = tk.Frame(root)
charts_frame.pack()

upper_frame = tk.Frame(charts_frame)
upper_frame.pack(fill="both", expand=True)

canvas1 = FigureCanvasTkAgg(fig1, upper_frame)
canvas1.draw()
canvas1.get_tk_widget().pack(side="left", fill="both", expand=True)

canvas2 = FigureCanvasTkAgg(fig2, upper_frame)
canvas2.draw()
canvas2.get_tk_widget().pack(side="left", fill="both", expand=True)

lower_frame = tk.Frame(charts_frame)
lower_frame.pack(fill="both", expand=True)

canvas4 = FigureCanvasTkAgg(fig4, lower_frame)
canvas4.draw()
canvas4.get_tk_widget().pack(side="left", fill="both", expand=True)

canvas5 = FigureCanvasTkAgg(fig5, lower_frame)
canvas5.draw()
canvas5.get_tk_widget().pack(side="left", fill="both", expand=True)

root.mainloop()

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("country_wise_latest.csv")
x=data['Recovered']
y=data['Deaths']
plt.rcParams["axes.prop_cycle"] = plt.cycler(
    color=["#4C2A85", "#BE96FF", "#957DAD", "#5E366E", "#A98CCC"])

fig3, ax3 = plt.subplots()
country_deaths = data[['Country/Region', 'Recovered']].sort_values(by='Recovered', ascending=False)
plt.bar(country_deaths['Country/Region'].head(10), country_deaths['Recovered'].head(10))
plt.xticks(rotation=80)
ax3.set_title("Recovered/Deaths Bar")
ax3.set_xlabel("Recovered")
ax3.set_ylabel("Deaths")

fig6, ax6 = plt.subplots()
recovered = data["Recovered"].sum()
death = data["Deaths"].sum()
data = [recovered, death]
labels = ["Recovered cases", "Deaths"]
ax6.set_title("Recovered/Deaths Pie")
ax6.set_xlabel("Recovered")
ax6.set_ylabel("Deaths")

pie = plt.pie(data, labels=labels, autopct="%.2f%%")

root = tk.Tk()
root.title("Dashboard")
root.state('zoomed')

side_frame = tk.Frame(root, bg="#4C2A85")
side_frame.pack(side="left", fill="y")

label = tk.Label(side_frame, text="Dashboard", bg="#4C2A85", fg="#FFF", font=25)
label.pack(pady=50, padx=20)

charts_frame = tk.Frame(root)
charts_frame.pack()

upper_frame = tk.Frame(charts_frame)
upper_frame.pack(fill="both", expand=True)

canvas3 = FigureCanvasTkAgg(fig3, upper_frame)
canvas3.draw()
canvas3.get_tk_widget().pack(side="right", fill="both", expand=True)


canvas6 = FigureCanvasTkAgg(fig6, upper_frame)
canvas6.draw()
canvas6.get_tk_widget().pack(side="right", fill="both", expand=True)

lower_frame = tk.Frame(charts_frame)
lower_frame.pack(fill="both", expand=True)


root.mainloop()
